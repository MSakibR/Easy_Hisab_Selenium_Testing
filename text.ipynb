# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# Create a Chrome browser controlled by Selenium
driver = webdriver.Chrome()

# Open a website
driver.get("https://www.yahoo.com")

print("Title of the page is:", driver.title)

# Close browser
driver.quit()
# Out:
# The chromedriver version (140.0.7339.207) detected in PATH at C:\webdriver\chromedriver.exe might not be compatible with the detected chrome version (141.0.7390.77); currently, chromedriver 141.0.7390.78 is recommended for chrome 141.*, so it is advised to delete the driver in PATH and retry
# Title of the page is: Yahoo! Australia | Mail, Weather, Search, Politics, News, Finance, Sports and Videos
